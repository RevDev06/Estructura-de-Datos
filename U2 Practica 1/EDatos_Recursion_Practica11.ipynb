# %% [markdown]
# ## Instituto Tecnologico de Aguascalientes
# ## Departamento: Sistemas y Computacion
# ## carrera: Ingenieria en ciberseguridad
# ## Materia: Estructura de datos
# ## Maestro:Dr. Fransisco Javier Luna Rosas
# ## Alumno: Mayrin Ximena Oliva Reyes
# ## Semestre: Agosto_Diciembre del 2026

# %% [markdown]
# # Unidad 2 Recursión
# ## 2.1.1 Definiciones recursivas
# ### Un objeto recursivo es aquel que aparece en la definicion de si mismo, en terminos simples, un metodo recursivo es un metodo que se llama asi mismo
# ### Se puede presentar de 2 formas distintas:
# ### La directa:
# ### Ocurre cuando un subprograma se llama a si mismo
# ### La indirecta:
# ### Un subprograma llama a otro subprograma y en algun momento volverá a llamar al subprograma original
# ### Cuando se diseña una solucion recursiva para un problema se necesitan hacer dos cosas:
# ### - Definir el caso base.
# ### - Definir la regla par el caso general
# ## 2.1.2 Ejemplos de casos recursvos
# ## Ejemplo 1: Imprimir "Hola Mundo" 100 veces

# %%
# Programa  recursivo oara imoprimir "Hello, World!" n veces
class RecusivoHelloWorld:
    # Metodo (funcion) recursivo
    def print_hello_world_n_times(n):
        
        # Caso base
        # Si n  es 0 o menor, no hacemos nada
        if n > 0:
            print("Hello, World!")
            # Llamada recursiva
            self.print_hello_world_n_times(n - 1)

    def __init__(self):
        pass

# Crear una instancia de la clase
objeto = RecusivoHelloWorld()
objeto.print_hello_world_n_times(5)  # Llamada inicial con n = 5
# Out:
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!
# Hello, World!

# %% [markdown]
# ## Conclusión
#
# ### En este proyecto medimos la cantidad de elementos que se pueden alamacenar en un algoritmo. Se expresa mediante la notacion Big O

# %% [markdown]
# ## Referencias
# ### 1. Araujo, SL, Martínez, UR, Rodríguez, AM (2011). Programación y estructuras de datos avanzadas. España: Centro de estudios. Ramón Areces.
# ### 2. Garrido Carrillo, A. & Valdivia Joaquín, F. (2006). Abstracción y estructura de datos en C++: (ed.). Publicaciones Delta.
# ### 3. Malik, DS (2013). Estructuras de datos con C++: (2 ed.). Aprendizaje Cengage.
# ### 4. Google. (2026). Gemini (Versión de agosto de 2026) [Modelo de lenguaje grande]. https://gemini.google.com
# ### 5. imagenes en python (Pillow, 2026) https://pillow.readthedocs.io/en/stable/ (Ultimo acceso Septiembre de 2026)
