# %% [markdown]
#  # Instituto Tecnologico de Aguascalientes
# # Departamento: Sistemas y Computacion
# # Carrera: Ingenieria en ciberseguridad
# ## Materia: Estructura de datos
# ## Maestro: Dr. Fransisco Javier Luna Rosas
# ## Alumno: Mayrin Ximena Oliva Reyes
# ### Semestre: Agosto_Diciembre del 2026

# %% [markdown]
# # Estructuras de Datos Dinámicas
# ## Las estructuras de datos lineales
# ### organizan los elementos de manera secuencial, donde cada elemento tiene un único predecesor y un único sucesor,
# ### facilitando el acceso y la manipulación de los datos.
#
# ## ¿Qué es un vector?
# ### Un vector es una estructura que permite guardar varios datos del mismo tipo.
#
# ## ¿Qué es un vector dinámico?
# ### Un vector dinámico es un vector cuyo tamaño se define desde el principio y no puede cambiar durante la ejecución.

# %% [markdown]
# # Practica 4:
# ## En esta practica implementaremos un programa en python utilizando arreglos dinamicos (estructuras de datos lineales dianmicas) para ordenar un vector de 5 números en forma ascendente

# %% [markdown]
# ## Paso 1: Importar las librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Paso 2: Crear un vector dinámico vacío

# %%
numeros = []

# %% [markdown]
# ## Paso 3: Capturar la cantidad de números a ordenar.

# %%
n = int(input("Ingrese la cantidad de números que desea ingresar: "))

# %% [markdown]
# ## Paso 4: Capturar los números:

# %%
for i in range(n):
    numero = float(input(f"Captura el número {i + 1}: "))
    numeros.append(numero)

# %% [markdown]
# ## Paso 5: Mostrar el vector original

# %%
print("Vector Original:")
print(numeros)
# Out:
# Vector Original:
# [33.0, 12.0, 45.0]

# %% [markdown]
# ## Paso 6: Ordenamos el vector aplicando Bubble Sort

# %%
for i in range(len(numeros)):
    for j in range(len(numeros) - 1 - i):
        if numeros[j] > numeros[j + 1]:
            numeros[j], numeros[j + 1] = numeros[j + 1], numeros[j]
# Out:
# Vector Ordenado:
# [12.0, 33.0, 45.0]

# %% [markdown]
# ## Paso 7: Mostrar el vector Ordenado

# %%
print("Vector Ordenado:")
print(numeros)
# Out:
# Vector Ordenado:
# [12.0, 33.0, 45.0]

# %% [markdown]
# ## Conclusiones:
# ### En esta practida implementamos un programa en Pyhton utilizando arreglos dinámicos (estructuras de datos lineales dinámicas), para ordenar un vector de N números de forma ascendente

# %% [markdown]
# ## Referencias
# ### 1. Araujo, SL, Martínez, UR, Rodríguez, AM (2011). Programación y estructuras de datos avanzadas. España: Centro de estudios. Ramón Areces.
# ### 2. Garrido Carrillo, A. & Valdivia Joaquín, F. (2006). Abstracción y estructura de datos en C++: (ed.). Publicaciones Delta.
# ### 3. Malik, DS (2013). Estructuras de datos con C++: (2 ed.). Aprendizaje Cengage.
# ### 4. Google. (2026). Gemini (Versión de agosto de 2026) [Modelo de lenguaje grande]. https://gemini.google.com
